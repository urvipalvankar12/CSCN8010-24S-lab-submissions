# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv('C:\\Users\\dhira\\OneDrive\\Desktop\\virat\\myenv\\diabetes.tab', delimiter='\t')

# Prepare the features (X) and target variable (Y)
X = df[['BMI']]
Y = df['Y']

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initialize and train the linear regression model
clf = LinearRegression()
clf.fit(x_train, y_train)

# Make predictions on both training and test sets
y_train_pred = clf.predict(x_train)
y_test_pred = clf.predict(x_test)

# Calculate evaluation metrics
mse_train = mean_squared_error(y_train, y_train_pred)
mae_train = mean_absolute_error(y_train, y_train_pred)

mse_test = mean_squared_error(y_test, y_test_pred)
mae_test = mean_absolute_error(y_test, y_test_pred)

# Print the evaluation metrics
print("Training Set:")
print("Mean Squared Error:", mse_train)
print("Mean Absolute Error:", mae_train)

print("\nTest Set:")
print("Mean Squared Error:", mse_test)
print("Mean Absolute Error:", mae_test)

# Calculate the absolute percentage error for training set
tolerance = 5.0
percentage_error_train = abs((y_train_pred - y_train) / y_train) * 100

# Calculate the absolute percentage error for test set
percentage_error_test = abs((y_test_pred - y_test) / y_test) * 100

# Calculate the percentage of correct predictions within the tolerance for training set
correct_predictions_train = (percentage_error_train <= tolerance).sum() / len(y_train) * 100

# Calculate the percentage of correct predictions within the tolerance for test set
correct_predictions_test = (percentage_error_test <= tolerance).sum() / len(y_test) * 100

# Print the accuracy
print("\nTraining Set - Percentage of Correct Predictions within ±{}%: {:.2f}%".format(tolerance, correct_predictions_train))
print("Test Set - Percentage of Correct Predictions within ±{}%: {:.2f}%".format(tolerance, correct_predictions_test))

# Plot actual vs predicted values for both sets
plt.figure(figsize=(12, 6))

# Plot for training set
plt.subplot(1, 2, 1)
plt.scatter(y_train, y_train_pred, color='blue', label='Actual', alpha=0.7)
plt.scatter(y_train, y_train, color='red', label='Predicted', alpha=0.7)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted (Training Set)')
plt.legend()

# Plot for test set
plt.subplot(1, 2, 2)
plt.scatter(y_test, y_test_pred, color='green', label='Actual', alpha=0.7)
plt.scatter(y_test, y_test, color='orange', label='Predicted', alpha=0.7)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted (Test Set)')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Training Set:
# Mean Squared Error: 3854.11265207582
# Mean Absolute Error: 51.37972765404718
#
# Test Set:
# Mean Squared Error: 4061.8259284949268
# Mean Absolute Error: 52.259976445345536
#
# Training Set - Percentage of Correct Predictions within ±5.0%: 5.95%
# Test Set - Percentage of Correct Predictions within ±5.0%: 5.62%

# %% [markdown]
# Considering the MSE and MAE lower the value better the performance but in my case or in this model am getting all the high value.
# That means this model might not be able to cover the aquired relationship between the BMI and Y and this is also the reason of why am getting
# the prediction percentage only 5% in both the cases may be i should change the relation by changing any one of them.
#   so according to me this is not the suitable model or may be am not able to create the model correct.
