# %% [markdown]
# Practical Lab 2 - Data Visualizations and Publication
#
# Data Visualization using Matplotlib

# %%
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Scatter Plot using matplotliib

# %%
x,y = np.random.randn(2,50)
sizes=np.random.randint(40,150,size=50)
plt.scatter(x,y,s=sizes , alpha=0.6)

# %% [markdown]
# Reading CSV file Using Pandas

# %%
data = pd.read_csv("D:\\Foundations of Machine learning\\CSCN8010-24S-lab-submissions\\students_submissions\\9006809_VishuGoyal\\R_HR_HRD_Datasheet_17052024_v1.csv")
data
# Out:
#      Age Age.Group  Gender Locality   Marital status                         \
# 0     45     41-50  Female      RURAL                               MARRIED
# 1     51     51-60  Female      URBAN                               MARRIED
# 2     55     51-60  Female      RURAL                               MARRIED
# 3     55     51-60  Female      RURAL                               MARRIED
# 4     56     51-60  Female      RURAL                               MARRIED
# ..   ...       ...     ...        ...                                   ...
# 363   55     51-60    Male      URBAN                               MARRIED
# 364   55     51-60    Male      RURAL                               MARRIED
# 365   58     51-60    Male      URBAN                               MARRIED
# 366   58     51-60    Male      URBAN                               MARRIED
# 367   50     41-50    Male      RURAL                               MARRIED
#
# ...

# %% [markdown]
# Histogram shows number of males and females affected by mental issues

# %%
plt.hist(x="Gender",data=data)
plt.xlabel('Gender')
plt.ylabel('Numbers of people')
# Out:
# Text(0, 0.5, 'Numbers of people')

# %%
linedata=np.random.randn(30)
x=np.arange(len(linedata))
y=np.cumsum(linedata)
plt.plot(x,y,c='green',linestyle="--",marker="o")

# %% [markdown]
# Pie Chart based on Indian Premier League play-offs winning chances

# %%
Teams=["RCB","KKR","RR","SRH"]
Winning_chances=np.random.randint(40,70,4)
explode_team=[0.1,0,0,0]
colors=['red','purple','pink','orange']
plt.pie(Winning_chances,labels=Teams,autopct="%1.0f%%", explode=explode_team , colors=colors)
# Out:
# ([<matplotlib.patches.Wedge at 0x16b1be4eb10>,
# ...
#  [Text(0.8006482399272817, 0.8938469644750974, 'RCB'),
#   Text(-0.8145983584540272, 0.739208708284747, 'KKR'),
#   Text(-0.7444589746802813, -0.8098029606132497, 'RR'),
#   Text(0.8145982892443099, -0.7392087845529461, 'SRH')],
#  [Text(0.4670448066242477, 0.52141072927714, '27%'),
#   Text(-0.44432637733856023, 0.40320474997349837, '23%'),
#   Text(-0.40606853164378975, -0.44171070578904525, '27%'),
#   Text(0.4443263395878053, -0.4032047915743342, '23%')])
