# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Loading the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# Extracting the BMI feature (third column in the dataset)
bmi_index = 2  # BMI is the third feature in the dataset
diabetes_X_bmi = diabetes_X[:, np.newaxis, bmi_index]

# Splitting the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(diabetes_X_bmi, diabetes_y, test_size=0.2, random_state=42)

# Creating and training the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Making predictions
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# Calculating the mean squared error
mse_train = mean_squared_error(y_train, y_train_pred)
mse_test = mean_squared_error(y_test, y_test_pred)

# Calculating RMSE
rmse_train = np.sqrt(mse_train)
rmse_test = np.sqrt(mse_test)

# Calculating R-squared
r2_train = r2_score(y_train, y_train_pred)
r2_test = r2_score(y_test, y_test_pred)

# Getting the model's parameters (slope and intercept)
slope = model.coef_[0]
intercept = model.intercept_

# Printing the results
print(f"Slope (Coefficient): {slope}")
print(f"Intercept: {intercept}")
print(f"Mean Squared Error on Training Set: {mse_train}")
print(f"Mean Squared Error on Test Set: {mse_test}")
print(f"Root Mean Squared Error on Training Set: {rmse_train}")
print(f"Root Mean Squared Error on Test Set: {rmse_test}")
print(f"R-squared on Training Set: {r2_train}")
print(f"R-squared on Test Set: {r2_test}")

# Plotting the training data and the model
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.plot(X_train, y_train_pred, color='red', linewidth=2, label='Linear regression model')
plt.xlabel('BMI')
plt.ylabel('Disease Progression')
plt.title('Training Data and Linear Regression Model')
plt.legend()
plt.show()

# Plotting the test data and the model 
plt.scatter(X_test, y_test, color='green', label='Test data')
plt.plot(X_test, y_test_pred, color='red', linewidth=2, label='Linear regression model')
plt.xlabel('BMI')
plt.ylabel('Disease Progression')
plt.title('Test Data and Linear Regression Model')
plt.legend()
plt.show()
# Out:
# Slope (Coefficient): 998.5776891375598
# Intercept: 152.00335421448167
# Mean Squared Error on Training Set: 3854.11265207582
# Mean Squared Error on Test Set: 4061.8259284949268
# Root Mean Squared Error on Training Set: 62.081500079136454
# Root Mean Squared Error on Test Set: 63.73245584860925
# R-squared on Training Set: 0.3657241273794126
# R-squared on Test Set: 0.23335039815872138
